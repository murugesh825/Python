# %%
from multiple_functions_def import multiple_functions

# %%
multiple_functions.Sub_Fields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
multiple_functions.Odd_Even()
# Out:
# Enter an number :  43543
# 43543 is Odd number
# -------------------------------------------------------

# %%
multiple_functions.Odd_Even()
# Out:
# Enter an number :  43452
# 43452 is Even number
# -------------------------------------------------------

# %%
multiple_functions.Marriage_Eligible()
# Out:
# Your Gender :  Male
# Your Age :  15
# You are not eilgible for Marriage
# -------------------------------------------------------

# %%
multiple_functions.Marriage_Eligible()
# Out:
# Your Gender :  Male
# Your Age :  25
# You are eligible for Marriage
# -------------------------------------------------------

# %%
multiple_functions.Marriage_Eligible()
# Out:
# Your Gender :  Female
# Your Age :  13
# You are not eilgible for Marriage
# -------------------------------------------------------

# %%
multiple_functions.Marriage_Eligible()
# Out:
# Your Gender :  Female
# Your Age :  22
# You are eligible for Marriage
# -------------------------------------------------------

# %%
multiple_functions.percentage()
# Out:
# Subject1 =  85
# Subject2 =  91
# Subject3 =  97
# Subject4 =  82
# Subject5 =  95
# Total =  450
# Percentage =  90.0

# %%
multiple_functions.area_perimeter()
# Out:
# Type A to calculate Area of a Triangle
# Type P to calcuate Perimeter of a Triangle
#  A
# Enter Height :  6
# Enter Breadth :  5
# Area Formula = (Height*Breadth)/2
# Area of Triangle 15.0
# *******************************************************

# %%
multiple_functions.area_perimeter()
# Out:
# Type A to calculate Area of a Triangle
# Type P to calcuate Perimeter of a Triangle
#  P
# Enter Height1 :  5
# Enter Height2 :  7
# Enter Breadth :  4
# Perimeter Formula = Height1 + Height2 + Breadth
# Perimeter of Triangle 16
# *******************************************************

# %%
multiple_functions.area_perimeter()
# Out:
# Type A to calculate Area of a Triangle
# Type P to calcuate Perimeter of a Triangle
#  D
# Invalid Input Type
# *******************************************************
