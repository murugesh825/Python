# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)

# Answer - Indentation error

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)

# Answer - Variable b is declared as string of 5. So, a print can not be performed with a and b

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b

# Answer - Indentation error. Fundction add_numbers should start from Column 1

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])

# Answer - Indentation error. List numbers should start from Column 1

# %%
#5.Find the error in the following Python code:
print "Hello, World!"

# Answer - print statement should always have open and close brackets.

# %%
#6.Find the error in the following Python code:
x = 5 / 0

# Answer - The division logic is Arithmatically wrong. We should not divide any number by Zero

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

# Answer - Variable 'name' is not defined. So, this print does not work

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# This for loop prints nothing because, the range is set from 1 to 10, so an interval of -1 can not be applied.
# This for loop works, if the range is given in reverse like 'for i in range(10,1,-1)'

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

# Answer - Singe equal sign is used for checking the if condition. We need to use double equal sign like 'if x == 5'

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)

# Anser - All function defniniton should end with a colon {:}. The colon (:) is missing in function definition (def).
