# %%
# 1. Scenario: A system checks if a user is eligible to vote based on their age.
# Write logic to ask the user for their age and determine if they are eligible to vote based on whether they are 18 or older.

age = int(input('Enter your age : '))

if age > 0 and age <= 100:
    if age >=18:
        print('You are eligible to vote')
    else:
        print('You are not eligible to vote')
else:
    print('Invalid Age. Tyr again')
# Out:
# Enter your age :  51
# You are eligible to vote

# %%
#2. Scenario: A program processes a list of numbers and needs to find the largest value.
# Write logic to identify and return the largest number from a given list.

n=int(input('Enter the number the list can hold = '))
L = []

for i in range(1,n+1):
    num=int(input('Enter Input # :'))
    L.append(num)

print(L)

largest = L[0]
for num1 in L[0:]:
    if num1 > largest:
        largest = num1

print('The Lagest of given list is : ',num1)
# Out:
# Enter the number the list can hold =  10
# Enter Input # : 5
# Enter Input # : 6
# Enter Input # : 43
# Enter Input # : 6
# Enter Input # : 7
# Enter Input # : 8
# Enter Input # : 85
# Enter Input # : 3
# Enter Input # : 5
# Enter Input # : 66
# [5, 6, 43, 6, 7, 8, 85, 3, 5, 66]
# The Lagest of given list is :  66

# %%
#3. Scenario: A company provides employees with a 10% bonus if their salary exceeds $50,000.
# Write logic to determine the bonus amount based on the given salary.

employee_id   = int(input('Enter Employee ID : '))
employee_name = input('Enter Employee Name : ')
employee_Sal  = int(input('Enter Employee Salary in $: '))

if employee_Sal >=50000:
    print("Dear. ", employee_name, ", You are eligible for 10% bonus which is ", employee_Sal*10/100)
else:
    print("Dear. ", employee_name, ", You are not eligible for 10% bonus")
# Out:
# Enter Employee ID :  438
# Enter Employee Name :  Murugesh S
# Enter Employee Salary in $:  54843
# Dear.  Murugesh S , You are eligible for 10% bonus which is  5484.3

# %%
# 4.Scenario: A program evaluates a number to determine if it is even or odd.
# Write logic to check whether a given number is even or odd.

n=int(input('Enter any number to determine if it is an even number or an odd number'))

if n%2==0:
    print('The given number is an even number')
else:
    print('The given number is an odd number')
# Out:
# Enter any number to determine if it is an even number or an odd number 55834985
# The given number is an odd number

# %%
# 5. Scenario: A text-processing tool reverses a given word or sentence for formatting purposes.
# Write logic to take a word or sentence as input and produce its reversed version.

text = input("Enter a word or sentence: ")
reversed_text = ""
for char in text:
    reversed_text = char + reversed_text
print("Reversed:", reversed_text)
# Out:
# Enter a word or sentence:  My name is Murugesh
# Reversed: hseguruM si eman yM

# %%
# 6. Scenario: A grading system determines whether a student has passed or failed based on their score.
# Write logic to check if a student has passed a subject by scoring at least 40 marks.

Student_ID =int(input('Enter Student ID : '))
Student_Name=input('Enter Student Name : ')
Mark1 = int(input('Enter Student Mark1 : '))
Mark2 = int(input('Enter Student Mark2 : '))
Mark3 = int(input('Enter Student Mark3 : '))
Mark4 = int(input('Enter Student Mark4 : '))
Mark5 = int(input('Enter Student Mark5 : '))

Total = Mark1 + Mark2 + Mark3 + Mark4 + Mark5
Average=round(Total/5,0)

if Mark1 >=40 and Mark2 >=40 and Mark3>=40 and Mark4>=40 and Mark5>=40:
    if Average>=40:
        print(Student_Name, 'has cleared all subjects')
    else:
        print(Student_Name, 'has failed')
else:
    print(Student_Name, 'has failed')
# Out:
# Enter Student ID :  544
# Enter Student Name :  Muru
# Enter Student Mark1 :  54
# Enter Student Mark2 :  54
# Enter Student Mark3 :  35
# Enter Student Mark4 :  76
# Enter Student Mark5 :  78
# Muru has failed

# %%
# 7. Scenario: A retail store offers a 20% discount if a customer’s total order exceeds $100. 
# Write logic to calculate the final amount to be paid after applying the discount.

final_amt=int(input('enter the final bill amout : '))

if final_amt>=100:
    print('You are eligible for 20% discount')
    print('20% discount',round(final_amt*20/100,2))
    print('Please pay ',final_amt - round(final_amt*20/100,2))
else:
    print('You are not eligible for 20% discount')
# Out:
# enter the final bill amout :  121
# You are eligible for 20% discount
# 20% discount 24.2
# Please pay  96.8

# %%
# 8. Scenario: A banking system processes withdrawal requests and ensures the user has enough balance.
# Write logic to check if a user has enough balance before allowing a withdrawal and update the remaining balance accordingly.

available_amount=int(input('Enter the available Bank Balance : '))
amt_to_withdraw=int(input('Enter the amount to be withdrawn : '))

if amt_to_withdraw > available_amount:
    print('Enter withdrawal amount can not be processed')
else:
    new_available_amount = available_amount - amt_to_withdraw
    print('Your withdrawal request is successful')
    print('New available balance : ',new_available_amount)
# Out:
# Enter the available Bank Balance :  58444
# Enter the amount to be withdrawn :  444
# Your withdrawal request is successful
# New available balance :  58000

# %%
#9. Scenario: A calendar system verifies whether a given year is a leap year based on standard leap year rules.
# Write logic to determine whether a given year is a leap year

leap_year=int(input('Enter any Year between 0 and 3000 to determine if it is a leap year : '))

if leap_year >0 and leap_year<=3000:
    if leap_year%4==0:
        print('The given year is a Leap Year')
    else:
        print('The given year is not a Leap Year')
else:
    print('Invalid input. Try Again')
# Out:
# Enter any Year between 0 and 3000 to determine if it is a leap year :  5343
# Invalid input. Try Again

# %%
# 10. Scenario: A program filters out only even numbers from a given list.
# Write logic to extract and return only the even numbers from a list.

n=int(input('Enter the number the list can hold = '))
L = []

for i in range(1,n+1):
    num=int(input('Enter Input # :'))
    L.append(num)

print(L)

even = []
for num1 in L[0:]:
    if num1%2 == 0:
        even.append(num1)

print('The even numbers from given list is : ',even)
# Out:
# Enter the number the list can hold =  6
# Enter Input # : 423
# Enter Input # : 3524
# Enter Input # : 354
# Enter Input # : 426
# Enter Input # : 6779
# Enter Input # : 23
# [423, 3524, 354, 426, 6779, 23]
# The even numbers from given list is :  [3524, 354, 426]
